// %%
#r "nuget: Avalonia, 11.3.12"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Avalonia, 11.3.12</span></li></ul></div></div>

// %%
using Avalonia;

// %%
new Rect(5, 10, 20, 30).Union(new Rect(0, 0, 0, 0)).Union(new Rect(2, 2, 10, 10))
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>2, 2, 23, 38</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>X</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>Y</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>Width</td><td><div class="dni-plaintext"><pre>23</pre></div></td></tr><tr><td>Height</td><td><div class="dni-plaintext"><pre>38</pre></div></td></tr><tr><td>Position</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>2, 2</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>X</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>Y</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Size</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>23, 38</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><t
// ...
